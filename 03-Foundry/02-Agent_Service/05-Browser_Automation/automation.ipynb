# %% [markdown]
# ## Using Browser Automation with Foundry Agent

# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
# Out:
# Requirement already satisfied: azure-ai-projects==2.0.0b2 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (2.0.0b2)
# Requirement already satisfied: openai==1.109.1 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (1.109.1)
# Requirement already satisfied: python-dotenv in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (1.2.1)
# Requirement already satisfied: azure-identity in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (1.25.2)
# Requirement already satisfied: isodate>=0.6.1 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from azure-ai-projects==2.0.0b2) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from azure-ai-projects==2.0.0b2) (1.38.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from azure-ai-projects==2.0.0b2) (12.28.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from openai==1.109.1) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from openai==1.109.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from openai==1.109.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from openai==1.109.1) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from openai==1.109.1) (2.12.5)
# Requirement already satisfied: sniffio in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from openai==1.109.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from openai==1.109.1) (4.67.3)
# Requirement already satisfied: idna>=2.8 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai==1.109.1) (3.11)
# Requirement already satisfied: certifi in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.4.2)
# Requirement already satisfied: cryptography>=2.5 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from azure-identity) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from azure-identity) (1.35.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (3.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.31.0->azure-identity) (2.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vijay/Desktop/Tavant/Microsoft Foundry/workspace/tavant_mf/.venv/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Setting Up the Environment Variables

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import PromptAgentDefinition, WebSearchPreviewTool, ApproximateLocation
from azure.ai.projects.models import BrowserAutomationToolConnectionParameters, BrowserAutomationToolParameters, BrowserAutomationAgentTool

load_dotenv()

foundry_project_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")
model_deployment_name = os.getenv("MODEL_DEPLOYMENT_NAME")
browser_automation_connection_name = os.getenv("BROWSER_AUTOMATION_CONNECTION_NAME")

# %% [markdown]
# ### Setting Up the Foundry Project Client

# %%
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential(),
)

# %% [markdown]
# ### Creating the OpenAI Client

# %%
openai_client = project_client.get_openai_client()

# %% [markdown]
# ### Fetching the Connection ID for the Browser Automation Tool

# %%
connection_id = ""

for connection in project_client.connections.list():
    if connection.name == browser_automation_connection_name:
        connection_id = connection.id
        break

print(f"The Browser Automation Tool Connection ID is: {connection_id}")
# Out:
# The Browser Automation Tool Connection ID is: /subscriptions/8bb477c6-092b-4864-b0fd-d10d75f245a9/resourceGroups/azurestalwart/providers/Microsoft.CognitiveServices/accounts/tavant-mf/projects/proj-default/connections/browserautomation_vijay

# %% [markdown]
# ### Creating the Browser Automation Tool Spec

# %%
tool = BrowserAutomationAgentTool(
    browser_automation_preview=BrowserAutomationToolParameters(
        connection = BrowserAutomationToolConnectionParameters(
            project_connection_id=connection_id
        )
    )
)

# %% [markdown]
# ### Creating the Agent

# %%
agent = project_client.agents.create_version(
    agent_name = "browser-automation-agent",
    definition=PromptAgentDefinition(
        model=model_deployment_name,
        tools=[tool],
        instructions="You are a helpful assistant that can automate web browser tasks using the Browser Automation Tool.",
    )
)

# %% [markdown]
# ### Creating a Conversation Object for the Agent Chat System

# %%
# create a conversation to use with the agent
conversation = openai_client.conversations.create()
print(f"Created conversation with id: {conversation.id}")
# Out:
# Created conversation with id: conv_643cd5ce3dfdf7b300Ai3bw79CRseAJIAmy9eTwyaZhaiTYnf7

# %% [markdown]
# ### Calling our Agent

# %%
user_query = """Your goal is to report the percent of Microsoft year-to-date stock price change.
            To do that, go to the website finance.yahoo.com.
            At the top of the page, you will find a search bar.
            Enter the value 'MSFT', to get information about the Microsoft stock price.
            At the top of the resulting page you will see a default chart of Microsoft stock price.
            Click on 'YTD' at the top of that chart, and report the percent value that shows up just below it."""

# %%
response = openai_client.responses.create(
    conversation=conversation.id,
    extra_body = {
        "agent": {
            "name": "browser-automation-agent",
            "type": "agent_reference"
        }
    },
    input=user_query
)

print(f"Agent Response: {response.output_text}")
# Out:
# Agent Response: The year-to-date (YTD) percent change for Microsoft Corporation (MSFT) is -18.79% according to Yahoo Finance.
